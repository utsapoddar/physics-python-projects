# %%
def recursive(n,a=0):
  if n==a:
    return ("done")
  else:
    print("doing")
    return recursive(n-1,a=0)
itterations = 10000 # Number of itterations to compute
itter_range = range(itterations)
print(range(1,len(itter_range)))
def r2(itterations,i=0):
  if itterations==1:
    return ("done")
  elif i==T_select[select]:
    plt.plot(x, T_list, label="Itteration: %d" % (i))
    select += 1
  else:
    interior_difference(T_list)
    return r2(itterations-1,i=0)
# Out:
# range(1, 10000)
